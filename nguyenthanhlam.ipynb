# %% [markdown]
# <a href="https://colab.research.google.com/github/thanhlamnguyen/AeThongMinh/blob/master/nguyenthanhlam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#0. Khai báo thư viện
from bs4 import BeautifulSoup
import requests
import os


#1. Cách lấy 1 phần tử đầu tiên ra khỏi list và xóa nó khỏi list
url_list = ["https://www.espn.com/nba/"]
url = url_list.pop(0)
print (url_list)
#2. Tải url về
page = requests.get(url)
soup = BeautifulSoup(page.text,"html.parser" )
html = soup.prettify()
print(html)
#3. Lưu 1 html vào thư mục chỉ định
f = open("chicken_html", "x")
f.write(html)
f.close()
#4. Cách lấy các url trong html
web = requests.get(url)
soup = BeautifulSoup(web.text,"html.parser")
for u in soup.find_all("a"):
      link = u.get("href")
      url_list.append(link)
print(url_list)
# Out:
# []
# <!DOCTYPE html>
# <html class="no-icon-fonts" lang="en">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <meta content="IE=edge,chrome=1" http-equiv="x-ua-compatible"/>
#   <meta content="initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
#   <meta content="origin-when-cross-origin" name="referrer"/>
#   <link href="https://www.espn.com/nba/" rel="canonical"/>
#   <title>
#    NBA - National Basketball Association Teams, Scores, Stats, News, Standings, Rumors - ESPN
#   </title>
#   <meta content="Get the latest NBA basketball news, scores, stats, standings, fantasy games, and more from ESPN." name="description">
#    <meta content="nba, national basketball association, pro basketball, nba basketball" name="news_keywords">
#     <meta content="nba, national basketball association, pro basketball, nba basketball" name="keywords"/>
#     <meta content="116656161708917" property="fb:app_id"/>
# ...
